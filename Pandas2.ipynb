# %%
#Reading excel file with pandas
#If you are using Visual Studio install Openpyxl library to read excel.
import pandas as pd
df= pd.read_excel('V13 DAX.xlsx',sheet_name="Sheet2")
df
# Out:
#   Receipt no   Location Customer name  Session id  Sale date   Status  \
# 0       BL11    Chennai          Naga          28 2020-03-06  Ordered
# 1       BL11    Chennai        Mahesh          28 2020-03-06  Ordered
# 2       BL12  Hyderabad        Ganesh          28 2020-03-06  Ordered
# 3       BL12    Chennai         Kumar          28        NaT  Ordered
# 4       BL12  Bangalore         Vijay          28 2020-03-06  Ordered
# 5       BL12  Bangalore         Sunil          28        NaT  Ordered
# 6       BL12    Chennai          Naga          28 2020-03-06  Ordered
# 7       BL11    Chennai        Mahesh          28 2020-03-06  Ordered
# 8       BL12  Hyderabad        Ganesh          28 2020-03-06  Ordered
#
#   Ordertype name  Token number   Product name Product Category  Cost Per Unit  \
# 0        On Shop             0   Jeans  Levis      Casual Wear            900
# 1            NaN             0         Tshirt      Semi Formal            400
# ...

# %%
nadf=df.dropna()

# %%
fnadf=df.fillna('TBD')

# %%
fnadf
# Out:
#   Receipt no   Location Customer name  Session id            Sale date  \
# 0       BL11    Chennai          Naga          28  2020-03-06 00:00:00
# 1       BL11    Chennai        Mahesh          28  2020-03-06 00:00:00
# 2       BL12  Hyderabad        Ganesh          28  2020-03-06 00:00:00
# 3       BL12    Chennai         Kumar          28                  TBD
# 4       BL12  Bangalore         Vijay          28  2020-03-06 00:00:00
# 5       BL12  Bangalore         Sunil          28                  TBD
# 6       BL12    Chennai          Naga          28  2020-03-06 00:00:00
# 7       BL11    Chennai        Mahesh          28  2020-03-06 00:00:00
# 8       BL12  Hyderabad        Ganesh          28  2020-03-06 00:00:00
#
#     Status Ordertype name  Token number   Product name Product Category  \
# 0  Ordered        On Shop             0   Jeans  Levis      Casual Wear
# 1  Ordered            TBD             0         Tshirt      Semi Formal
# ...

# %%
#remove the rows having empty columns
newdf=df.dropna()
newdf
# Out:
#   Receipt no Location Customer name  Session id  Sale date   Status  \
# 0       BL11  Chennai          Naga          28 2020-03-06  Ordered
# 6       BL12  Chennai          Naga          28 2020-03-06  Ordered
#
#   Ordertype name  Token number   Product name Product Category  Cost Per Unit  \
# 0        On Shop             0   Jeans  Levis      Casual Wear            900
# 6        On Shop             0   Jeans  Levis      Casual Wear            900
#
#    Selling Per Unit  Quantity
# 0              1100       1.0
# 6              1100       2.0

# %%
# Set value for specific column based on row values
df.loc[df['Customer name'] == "Kumar", 'Sale date'] = "09-10-2024"

df.loc[
# Out:
#   Cell In[32], line 4
#     df.loc[,]
#            ^
# SyntaxError: invalid syntax

# %%
# Set value for specific column based on row values
df.loc[df['Product Category'].isna(), 'Product Category']="TBD"
df
# Out:
#   Receipt no   Location Customer name  Session id            Sale date  \
# 0       BL11    Chennai          Naga          28  2020-03-06 00:00:00
# 1       BL11    Chennai        Mahesh          28  2020-03-06 00:00:00
# 2       BL12  Hyderabad        Ganesh          28  2020-03-06 00:00:00
# 3       BL12    Chennai         Kumar          28                  NaT
# 4       BL12  Bangalore         Vijay          28                  TBD
# 5       BL12  Bangalore         Sunil          28                  NaT
# 6       BL12    Chennai          Naga          28  2020-03-06 00:00:00
# 7       BL11    Chennai        Mahesh          28  2020-03-06 00:00:00
# 8       BL12  Hyderabad        Ganesh          28  2020-03-06 00:00:00
#
#     Status Ordertype name  Token number   Product name Product Category  \
# 0  Ordered        On Shop             0   Jeans  Levis      Casual Wear
# 1  Ordered            NaN             0         Tshirt      Semi Formal
# ...

# %%
# Set value for specific column based on more the one row values
df.loc[(df['Customer name'] == "Kumar") | (df['Customer name'] == "Sunil"), 'Sale date'] = "09-10-2024"

# %%
df
# Out:
#   Receipt no   Location Customer name  Session id  Sale date   Status  \
# 0       BL11    Chennai          Naga          28 2020-03-06  Ordered
# 1       BL11    Chennai        Mahesh          28 2020-03-06  Ordered
# 2       BL12  Hyderabad        Ganesh          28 2020-03-06  Ordered
# 3       BL12    Chennai         Kumar          28 2024-09-10  Ordered
# 4       BL12  Bangalore         Vijay          28 2020-03-06  Ordered
# 5       BL12  Bangalore         Sunil          28 2024-09-10  Ordered
# 6       BL12    Chennai          Naga          28 2020-03-06  Ordered
# 7       BL11    Chennai        Mahesh          28 2020-03-06  Ordered
# 8       BL12  Hyderabad        Ganesh          28 2020-03-06  Ordered
#
#   Ordertype name  Token number   Product name Product Category  Cost Per Unit  \
# 0        On Shop             0   Jeans  Levis      Casual Wear            900
# 1            NaN             0         Tshirt      Semi Formal            400
# ...

# %%
# Set or Fill NaN or NaT values (Missing Values) with values
fillDF = df.fillna(0)
fillDF
# Out:
#   Receipt no   Location Customer name  Session id  Sale date   Status  \
# 0       BL11    Chennai          Naga          28 2020-03-06  Ordered
# 1       BL11    Chennai        Mahesh          28 2020-03-06  Ordered
# 2       BL12  Hyderabad        Ganesh          28 2020-03-06  Ordered
# 3       BL12    Chennai         Kumar          28 2024-09-10  Ordered
# 4       BL12  Bangalore         Vijay          28 2020-03-06  Ordered
# 5       BL12  Bangalore         Sunil          28 2024-09-10  Ordered
# 6       BL12    Chennai          Naga          28 2020-03-06  Ordered
# 7       BL11    Chennai        Mahesh          28 2020-03-06  Ordered
# 8       BL12  Hyderabad        Ganesh          28 2020-03-06  Ordered
#
#   Ordertype name  Token number   Product name Product Category  Cost Per Unit  \
# 0        On Shop             0   Jeans  Levis      Casual Wear            900
# 1              0             0         Tshirt      Semi Formal            400
# ...

# %%
# Set or Fill NaN or NaT values (Missing Values) with values
df.loc[df['Quantity'].isna(), 'Quantity'] = 0
df
# Out:
#   Receipt no   Location Customer name  Session id  Sale date   Status  \
# 0       BL11    Chennai          Naga          28 2020-03-06  Ordered
# 1       BL11    Chennai        Mahesh          28 2020-03-06  Ordered
# 2       BL12  Hyderabad        Ganesh          28 2020-03-06  Ordered
# 3       BL12    Chennai         Kumar          28 2024-09-10  Ordered
# 4       BL12  Bangalore         Vijay          28 2020-03-06  Ordered
# 5       BL12  Bangalore         Sunil          28 2024-09-10  Ordered
# 6       BL12    Chennai          Naga          28 2020-03-06  Ordered
# 7       BL11    Chennai        Mahesh          28 2020-03-06  Ordered
# 8       BL12  Hyderabad        Ganesh          28 2020-03-06  Ordered
#
#   Ordertype name  Token number   Product name Product Category  Cost Per Unit  \
# 0        On Shop             0   Jeans  Levis      Casual Wear            900
# 1            NaN             0         Tshirt      Semi Formal            400
# ...

# %%
#Pandas DataFrame Fileters
Fileterdf =df[df['Customer name'] == "Ganesh"]
Fileterdf
# Out:
#   Receipt no   Location Customer name  Session id  Sale date   Status  \
# 2       BL12  Hyderabad        Ganesh          28 2020-03-06  Ordered
# 8       BL12  Hyderabad        Ganesh          28 2020-03-06  Ordered
#
#   Ordertype name  Token number Product name Product Category  Cost Per Unit  \
# 2        On Shop             0       Wallet      Accessories            300
# 8        On Shop             0       Wallet      Accessories            300
#
#    Selling Per Unit Quantity
# 2               500      0.0
# 8               500      0.0

# %%
#Pandas DataFrame.where()
#rows having particular Value will be shown and rest will be replaced by NaN using .where() method.
filter1=df['Customer name'] =="Naga"
df1=df.where((df['Location']=="Chennai")  & filter1)
df1
# Out:
#   Receipt no Location Customer name  Session id  Sale date   Status  \
# 0       BL11  Chennai          Naga        28.0 2020-03-06  Ordered
# 1        NaN      NaN           NaN         NaN        NaT      NaN
# 2        NaN      NaN           NaN         NaN        NaT      NaN
# 3        NaN      NaN           NaN         NaN        NaT      NaN
# 4        NaN      NaN           NaN         NaN        NaT      NaN
# 5        NaN      NaN           NaN         NaN        NaT      NaN
# 6       BL12  Chennai          Naga        28.0 2020-03-06  Ordered
# 7        NaN      NaN           NaN         NaN        NaT      NaN
# 8        NaN      NaN           NaN         NaN        NaT      NaN
#
#   Ordertype name  Token number   Product name Product Category  Cost Per Unit  \
# 0        On Shop           0.0   Jeans  Levis      Casual Wear          900.0
# 1            NaN           NaN            NaN              NaN            NaN
# ...

# %%
df
# Out:
#   Receipt no   Location Customer name  Session id  Sale date   Status  \
# 0       BL11    Chennai          Naga          28 2020-03-06  Ordered
# 1       BL11    Chennai        Mahesh          28 2020-03-06  Ordered
# 2       BL12  Hyderabad        Ganesh          28 2020-03-06  Ordered
# 3       BL12    Chennai         Kumar          28        NaT  Ordered
# 4       BL12  Bangalore         Vijay          28 2020-03-06  Ordered
# 5       BL12  Bangalore         Sunil          28        NaT  Ordered
# 6       BL12    Chennai          Naga          28 2020-03-06  Ordered
# 7       BL11    Chennai        Mahesh          28 2020-03-06  Ordered
# 8       BL12  Hyderabad        Ganesh          28 2020-03-06  Ordered
#
#   Ordertype name  Token number   Product name Product Category  Cost Per Unit  \
# 0        On Shop             0   Jeans  Levis      Casual Wear            900
# 1            NaN             0         Tshirt      Semi Formal            400
# ...

# %%
#nlargest() method is used to get n largest values from a data frame or a series.
#Smallest() method is used to get n largest values from a data frame or a series.
#'first': Keep the first occurrence of tied values.
#'last': Keep the last occurrence of tied values.
#'all': Keep all occurrences of tied values. This can return more than 2 rows if there are ties.

top_2_expensive = df.nlargest(2, 'Cost Per Unit', keep='first')
top_2_expensive
# Out:
#   Receipt no   Location Customer name  Session id  Sale date   Status  \
# 0       BL11    Chennai          Naga          28 2020-03-06  Ordered
# 4       BL12  Bangalore         Vijay          28 2020-03-06  Ordered
#
#   Ordertype name  Token number   Product name Product Category  Cost Per Unit  \
# 0        On Shop             0   Jeans  Levis      Casual Wear            900
# 4        On Shop             0   Shirt  Arrow              NaN            900
#
#    Selling Per Unit  Quantity
# 0              1100       1.0
# 4              1100       1.0

# %%
# dropping passed columns
dfCopy=df
drpDF=dfCopy.drop(["Location", "Session id"], axis = 1, inplace = True)

# %%
dfCopy
# Out:
#   Receipt no Customer name  Sale date   Status Ordertype name  Token number  \
# 0       BL11          Naga 2020-03-06  Ordered        On Shop             0
# 1       BL11        Mahesh 2020-03-06  Ordered            NaN             0
# 2       BL12        Ganesh 2020-03-06  Ordered        On Shop             0
# 3       BL12         Kumar        NaT  Ordered        On Shop             0
# 4       BL12         Vijay 2020-03-06  Ordered        On Shop             0
# 5       BL12         Sunil        NaT  Ordered        On Shop             0
# 6       BL12          Naga 2020-03-06  Ordered        On Shop             0
# 7       BL11        Mahesh 2020-03-06  Ordered            NaN             0
# 8       BL12        Ganesh 2020-03-06  Ordered        On Shop             0
#
#     Product name Product Category  Cost Per Unit  Selling Per Unit  Quantity
# 0   Jeans  Levis      Casual Wear            900              1100       1.0
# ...

# %%
#Read Json file with Pandas
import pandas   as pd
pd.options.display.max_rows=9999

    
jsdf
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...
