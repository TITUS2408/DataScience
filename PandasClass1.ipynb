# %% [markdown]
# <a href="https://colab.research.google.com/github/TITUS2408/DataScience/blob/main/PandasClass1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pands as pd

# %%
df['Cost Amount']

# %%
#Find the max Cost amount
max_cost=df['Cost Amount'].max()

# %%
#Find the Max Cost amount productName
# Use .loc to select rows based on given filter condition using lables
# df.loc[row Value, Column Values]
#To get all the columns
df.loc[df['Cost Amount']==max_cost,:]
# Out:
#      Receipt no   Location Customer name  Session id  Sale date   Status  \
# 273        BL94  Hyderabad         Kumar          28 2020-03-09  Ordered
# 349       BL128  Bangalore         Vijay          28 2020-03-11  Ordered
# 910        BL94    Chennai        Mahesh          28 2020-02-09  Ordered
# 995        BL94  Hyderabad         Sunil          28 2020-01-09  Ordered
# 1294       BL94    Chennai         Vijay          28 2019-03-09  Ordered
# 1363      BL128    Chennai         Vijay          28 2019-03-11  Ordered
# 1889       BL94  Hyderabad         Sunil          28 2019-02-09  Ordered
# 1969       BL94    Chennai         Vijay          28 2019-01-09  Ordered
# 2251       BL94  Hyderabad        Mahesh          28 2019-04-09  Ordered
# 2320      BL128    Chennai        Mahesh          28 2019-04-11  Ordered
# 2789       BL94  Bangalore         Sunil          28 2019-05-09  Ordered
# 2869       BL94  Hyderabad         Vijay          28 2019-06-09  Ordered
# ...

# %%
#to get the specific columns with Loc
df.loc[df['Cost Amount']==max_cost, [ 'Receipt no','Product name','Ordertype name', 'Cost Amount']]
# Out:
#      Receipt no   Product name Ordertype name  Cost Amount
# 273        BL94   Jeans  Levis        On Shop         2700
# 349       BL128   Jeans  Levis   Online Order         2700
# 910        BL94   Jeans  Levis        On Shop         2700
# 995        BL94   Jeans  Levis        On Shop         2700
# 1294       BL94   Jeans  Levis        On Shop         2700
# 1363      BL128   Jeans  Levis   Online Order         2700
# 1889       BL94   Jeans  Levis        On Shop         2700
# 1969       BL94   Jeans  Levis        On Shop         2700
# 2251       BL94   Jeans  Levis        On Shop         2700
# 2320      BL128   Jeans  Levis   Online Order         2700
# 2789       BL94   Jeans  Levis        On Shop         2700
# 2869       BL94   Jeans  Levis        On Shop         2700
# 3130       BL94   Jeans  Levis        On Shop         2700
# 3199      BL128   Jeans  Levis   Online Order         2700
# 3701       BL94   Jeans  Levis        On Shop         2700
# ...

# %%
# to get the range of rows with .loc method ===>range value should be given with :
df.loc[0:5, ['Receipt no','Product name','Ordertype name', 'Cost Amount']]
# Out:
#   Receipt no   Product name Ordertype name  Cost Amount
# 0       BL11   Jeans  Levis        On Shop          900
# 1       BL11   Jeans  Levis        On Shop          900
# 2       BL12   Jeans  Levis        On Shop          900
# 3       BL12   Jeans  Levis        On Shop          900
# 4       BL12   Jeans  Levis        On Shop          900
# 5       BL12   Jeans  Levis        On Shop          900

# %%
#to get all the rows with all columns using .loc function
df.loc[:,:]
# Out:
#   Receipt no   Location Customer name  Session id  Sale date   Status  \
# 1       BL11    Chennai        Mahesh          28 2020-03-06  Ordered
# 2       BL12  Hyderabad        Ganesh          28 2020-03-06  Ordered
# 3       BL12    Chennai         Kumar          28 2020-03-06  Ordered
#
#   Ordertype name  Token number   Product name Product Category  Cost Per Unit  \
# 1        On Shop             0   Jeans  Levis      Casual Wear            900
# 2        On Shop             0   Jeans  Levis      Casual Wear            900
# 3        On Shop             0   Jeans  Levis      Casual Wear            900
#
#    Selling Per Unit  Quantity  Cost Amount  Sales Amount  Profit
# 1              1100         1          900          1100     200
# 2              1100         1          900          1100     200
# 3              1100         1          900          1100     200

# %%
#to get all the rows with range of columns using column names .loc function
df.loc[:,'Receipt no':'Session id'] #here you can replace the column lables with .iloc indices if you want
# Out:
#   Receipt no   Location Customer name  Session id  Sale date
# 1       BL11    Chennai        Mahesh          28 2020-03-06
# 2       BL12  Hyderabad        Ganesh          28 2020-03-06

# %%
'''.iloc[]
It allows users to select specific rows and columns
by providing integer indices, making it a valuable tool for data
manipulation and extraction based on numerical positions within the DataFrame'''
df.iloc[1:3,0:5]
# Out:
#   Receipt no   Location Customer name  Session id  Sale date
# 1       BL11    Chennai        Mahesh          28 2020-03-06
# 2       BL12  Hyderabad        Ganesh          28 2020-03-06

# %%
# get s specific sell value by giving [row index, column index] with .iloc function
location=df.iloc[0,1]
location

#
# Out:
# 'Chennai'

# %%
#Get the unique records from the table or dataframe
distinct_locatins=df['Ordertype name'].unique()

otDF=pd.DataFrame({'DistinctLocations':distinct_locatins})
otDF.to_csv('DistinctLocations.csv',index=False)

# %%
#using pandas to convert the dictionry as a table or data frame
StuRec={'Students':{'name':['titus','angel','Naveena'],'Age':[27,18,25]}}
stuDF=pd.DataFrame(StuRec['Students'])
stuDF
# Out:
#       name  Age
# 0    titus   27
# 1    angel   18
# 2  Naveena   25

# %%
#use the tail method to print last n records
stuDF.tail(2)
# Out:
#       name  Age
# 1    angel   18
# 2  Naveena   25

# %%
#Write dataframe into a file
#give index=False to avoid the index value also get written in the csv file
stuDF.to_csv('Students.csv',index=False)

# %%
#use head function to read the top n records
stuDF.head(2)
# Out:
#     name  Age
# 0  titus   27
# 1  angel   18

# %%
#to check the max rows to be rueturned
pd.options.display.max_rows
# Out:
# 60

# %%
#To increase the max rows to be returned
pd.options.display.max_rows=9999
